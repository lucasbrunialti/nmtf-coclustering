# %%
import subprocess
import numpy as np
import h5py

from numpy import genfromtxt
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
# %matplotlib inline

# %%
h5f = h5py.File('data.h5','r')
X = h5f['X'][:]
h5f.close()

# %%
plt.matshow(X.T, cmap=plt.cm.Blues)
plt.title('X')
plt.grid()
plt.show()

# %%
# %%time
proc = subprocess.Popen(['g++', '-O3', '-DNDEBUG', 'algos.cpp', '-o', 'algos', '-larmadillo', '-llapack', '-lblas'],
                        stdin = subprocess.PIPE,
                        stdout = subprocess.PIPE,
                        stderr = subprocess.PIPE)

(out, err) = proc.communicate()
print 'out:', out
print 'err:', err
# Out:
# out:
# err:
# CPU times: user 1 ms, sys: 4.25 ms, total: 5.25 ms
# Wall time: 3.1 s

# %%
# %%time
proc = subprocess.Popen(['./algos', 'onmtf', '3', '2', '10000'],
                        stdin = subprocess.PIPE,
                        stdout = subprocess.PIPE,
                        stderr = subprocess.PIPE)

(out, err) = proc.communicate()
print 'out:', out
print 'err:', err
# Out:
# out: Reading X...  read 6 rows and 8 cols!
# U S V created
# Error obtained: 6.59541
# Error obtained: 5.01806
# Error obtained: 4.89341
# Error obtained: 4.84618
# Error obtained: 4.8322
# Error obtained: 4.82017
# Error obtained: 4.80821
# Error obtained: 4.79531
# Error obtained: 4.78082
# Error obtained: 4.76427
# Error obtained: 4.74488
# Error obtained: 4.72215
# Error obtained: 4.69489
# Error obtained: 4.66236
# Error obtained: 4.62283
# Error obtained: 4.57499
# Error obtained: 4.51637
# Error obtained: 4.44467
# Error obtained: 4.35624
# Error obtained: 4.24714
# Error obtained: 4.11195
# Error obtained: 3.9449
# Error obtained: 3.7398
# Error obtained: 3.49244
# Error obtained: 3.20172
# Error obtained: 2.87023
# Error obtained: 2.5004
# Error obtained: 2.09519
# Error obtained: 1.67167
# Error obtained: 1.27629
# Error obtained: 0.955223
# Error obtained: 0.713373
# Error obtained: 0.529275
# Error obtained: 0.387138
# Error obtained: 0.27939
# Error obtained: 0.200685
# Error obtained: 0.14486
# Error obtained: 0.105923
# Error obtained: 0.078838
# Error obtained: 0.0598943
# Error obtained: 0.0464928
# Error obtained: 0.0368695
# Error obtained: 0.0298374
# Error obtained: 0.024599
# Error obtained: 0.0206193
# Error obtained: 0.0175365
# Error obtained: 0.0151042
# Error obtained: 0.0131523
# Error obtained: 0.0115616
# Error obtained: 0.0102473
# Error obtained: 0.0091478
# Error obtained: 0.00821786
# Error obtained: 0.00742366
# Error obtained: 0.00673942
# Error obtained: 0.00614538
# Error obtained: 0.00562599
# Error obtained: 0.00516913
# Error obtained: 0.00476493
# Error obtained: 0.00440558
# Error obtained: 0.00408456
# Error obtained: 0.00379665
# Error obtained: 0.00353735
# Error obtained: 0.00330308
# Error obtained: 0.00309064
# Error obtained: 0.00289749
# Error obtained: 0.00272131
# Error obtained: 0.00256025
# Error obtained: 0.00241258
# Error obtained: 0.00227694
# Error obtained: 0.00215201
# Error obtained: 0.00203676
# Error obtained: 0.00193019
# Error obtained: 0.0018315
# Error obtained: 0.0017399
# Error obtained: 0.00165478
# Error obtained: 0.00157552
# Error obtained: 0.00150165
# Error obtained: 0.00143264
# Error obtained: 0.00136814
# Error obtained: 0.00130773
# Error obtained: 0.00125111
# Error obtained: 0.00119795
# Error obtained: 0.001148
# Error obtained: 0.00110099
# Error obtained: 0.00105672
# Error obtained: 0.00101497
# Error obtained: 0.000975578
# Error obtained: 0.000938345
# Error obtained: 0.000903146
# Error obtained: 0.000869816
# Error obtained: 0.00083825
# Error obtained: 0.000808307
# Error obtained: 0.000779903
# Error obtained: 0.000752914
# Error obtained: 0.000727272
# Error obtained: 0.00070287
# Error obtained: 0.000679653
# Error obtained: 0.000657527
# Error obtained: 0.000636445
# Error obtained: 0.000616328
# Error obtained: 0.000597135
# Error obtained: 0.000578797
# Error obtained: 0.000561281
# Error obtained: 0.000544526
# Error obtained: 0.000528502
# Error obtained: 0.000513157
# Error obtained: 0.000498467
# Error obtained: 0.000484383
# Error obtained: 0.000470887
# Error obtained: 0.000457935
# Error obtained: 0.000445511
# Error obtained: 0.000433576
# Error obtained: 0.000422117
# Error obtained: 0.000411099
# Error obtained: 0.000400511
# Error obtained: 0.000390322
# Error obtained: 0.000380522
# Error obtained: 0.000371083
# Error obtained: 0.000361997
# Error obtained: 0.000353238
# Error obtained: 0.000344801
# Error obtained: 0.000336661
# Error obtained: 0.000328814
# Error obtained: 0.000321237
# Error obtained: 0.000313928
# Error obtained: 0.000306866
# Error obtained: 0.000300048
# Error obtained: 0.000293457
# Error obtained: 0.000287089
# Error obtained: 0.000280928
# Error obtained: 0.000274972
# Error obtained: 0.000269207
# Error obtained: 0.00026363
# Error obtained: 0.000258227
# Error obtained: 0.000252998
# Error obtained: 0.00024793
# Error obtained: 0.000243021
# Error obtained: 0.000238261
# Error obtained: 0.000233648
# Error obtained: 0.000229172
# Error obtained: 0.000224833
# Error obtained: 0.00022062
# Error obtained: 0.000216533
# Error obtained: 0.000212564
# Error obtained: 0.000208711
# Error obtained: 0.000204967
# Error obtained: 0.000201332
# Error obtained: 0.000197797
# Error obtained: 0.000194364
# Error obtained: 0.000191024
# Error obtained: 0.000187778
# Error obtained: 0.000184619
# Error obtained: 0.000181547
# Error obtained: 0.000178557
# Error obtained: 0.000175648
# Error obtained: 0.000172816
# Error obtained: 0.000170059
# Error obtained: 0.000167373
# Error obtained: 0.000164758
# Error obtained: 0.000162209
# Error obtained: 0.000159727
# Error obtained: 0.000157306
# Error obtained: 0.000154948
# Error obtained: 0.000152648
# Error obtained: 0.000150406
# Error obtained: 0.000148218
# Error obtained: 0.000146085
# Error obtained: 0.000144003
# Error obtained: 0.000141973
# Error obtained: 0.00013999
# Error obtained: 0.000138056
# Error obtained: 0.000136167
# Error obtained: 0.000134323
# Error obtained: 0.000132521
# Error obtained: 0.000130762
# Error obtained: 0.000129043
# Error obtained: 0.000127365
# Error obtained: 0.000125723
# Error obtained: 0.00012412
# Error obtained: 0.000122552
# Error obtained: 0.00012102
# Error obtained: 0.000119522
# Error obtained: 0.000118057
# Error obtained: 0.000116624
# Error obtained: 0.000115223
# Error obtained: 0.000113851
# Error obtained: 0.00011251
# Error obtained: 0.000111197
# Error obtained: 0.000109912
# Error obtained: 0.000108655
# Error obtained: 0.000107424
# Error obtained: 0.000106219
# Error obtained: 0.000105039
# Error obtained: 0.000103883
# Error obtained: 0.000102752
# Error obtained: 0.000101643
# Error obtained: 0.000100557
# Error obtained: 9.94927e-05
# Error obtained: 9.84505e-05
# Error obtained: 9.74285e-05
# Error obtained: 9.64275e-05
# Error obtained: 9.54458e-05
# Du:
#    2.2597        0        0
#         0   2.2398        0
#         0        0   2.2558
# Dv:
#    4.1509        0
#         0   4.1586
# Time taken: 0.003821
#
# err:
# CPU times: user 1.44 ms, sys: 5.74 ms, total: 7.19 ms
# Wall time: 18 ms

# %%
float(open('error.csv').read())
# Out:
# 0.00037281

# %%
U = genfromtxt('U.csv', delimiter=',')
S = genfromtxt('S.csv', delimiter=',')
V = genfromtxt('V.csv', delimiter=',')

# %%
plt.matshow(U, cmap=plt.cm.Blues)
plt.title('U')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.matshow(S, cmap=plt.cm.Blues)
plt.title('S')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.matshow(V.T, cmap=plt.cm.Blues)
plt.title('V')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
def generate_dataset(option, noise=1, noise_background=True, shuffle=False):
    shape = (150, 150)
    n, m = shape
    
    # values can't be a lot far...
    centers = [20, 40, 60, 80, 100, 120, 140, 160, 180]
    
    y_row = np.zeros(150)
    y_col = np.zeros(150)

    if noise_background:
        data = np.random.rand(n, m) * 100
    else:
        data = np.zeros(n * m).reshape(shape) + np.random.uniform(0, 1, n*m).reshape(shape)

    if option == 'a':
        data[60:110][:, 70:140] = np.random.rand(50, 70) * noise + centers[0]
        y_row[60:110] = 1
        y_col[70:140] = 1
    elif option == 'b':
        data[0:50][:, 0:50] = np.random.rand(50, 50) * noise + centers[3]
        y_row[0:50] = 0
        y_col[0:50] = 0

        data[50:100][:, 50:100] = np.random.rand(50, 50) * noise + centers[1]
        y_row[50:100] = 1
        y_col[50:100] = 1

        data[100:150][:, 100:150] = np.random.rand(50, 50) * noise + centers[2]
        y_row[100:150] = 2
        y_col[100:150] = 2
    elif option == 'c':
        data[0:50][:, 0:50] = np.random.rand(50, 50) * noise + centers[0]
        y_row[0:50] = 0
        y_col[0:50] = 0

        data[0:50][:, 50:100] = np.random.rand(50, 50) * noise + centers[7]
        y_col[50:100] = 1

        data[0:50][:, 100:150] = np.random.rand(50, 50) * noise + centers[3]
        y_col[100:150] = 2

        data[50:100][:, 0:50] = np.random.rand(50, 50) * noise + centers[2]
        y_row[0:50] = 1

        data[50:100][:, 50:100] = np.random.rand(50, 50) * noise + centers[4]

        data[50:100][:, 100:150] = np.random.rand(50, 50) * noise + centers[8]

        data[100:150][:, 0:50] = np.random.rand(50, 50) * noise + centers[6]
        y_row[100:150] = 2

        data[100:150][:, 50:100] = np.random.rand(50, 50) * noise + centers[1]

        data[100:150][:, 100:150] = np.random.rand(50, 50) * noise + centers[5]
    elif option == 'd':
        data[0:50][:, 0:70] = np.random.rand(50, 70) * noise + centers[0]
        y_row[0:50] = 0
        y_col[0:70] = 0

        data[50:100][:, 50:100] = np.random.rand(50, 50) * noise + centers[2]
        y_row[50:100] = 1
        y_col[50:100] = 1

        data[100:150][:, 80:150] = np.random.rand(50, 70) * noise + centers[1]
        y_row[100:150] = 2
        y_col[80:150] = 2
    elif option == 'e':
        data[0:70][:, 0:50] = np.random.rand(70, 50) * noise + centers[3]
        y_row[0:70] = 0
        y_col[0:50] = 0

        data[50:100][:, 50:100] = np.random.rand(50, 50) * noise + centers[1]
        y_row[50:100] = 1
        y_col[50:100] = 1

        data[80:150][:, 100:150] = np.random.rand(70, 50) * noise + centers[2]
        y_row[80:150] = 2
        y_col[100:150] = 2
    elif option == 'f':
        data[0:50][:, 0:40] = np.random.rand(50, 40) * noise + centers[4]
        y_row[0:50] = 0
        y_col[0:40] = 0

        data[50:150][:, 0:40] = np.random.rand(100, 40) * noise + centers[0]
        y_row[50:150] = 1

        data[110:150][:, 40:95] = np.random.rand(40, 55) * noise + centers[2]
        y_row[110:150] = 2
        y_col[40:95] = 1

        data[110:150][:, 95:150] = np.random.rand(40, 55) * noise + centers[1]
        y_col[95:150] = 2
    elif option == 'g':
        data[0:110][:, 0:40] = np.random.rand(110, 40) * noise + centers[0]
        data[110:150][:, 0:110] = np.random.rand(40, 110) * noise + centers[2]
        data[40:150][:, 110:150] = np.random.rand(110, 40) * noise + centers[1]
        data[0:40][:, 40:150] = np.random.rand(40, 110) * noise + centers[3]
    elif option == 'h':
        data[0:90][:, 0:90] = np.random.rand(90, 90) * noise + centers[0]
        data[35:55][:, 35:55] = (np.random.rand(20, 20) * noise + centers[1]) + data[35:55][:, 35:55]
        data[110:140][:, 35:90] = np.random.rand(30, 55) * noise + centers[4]
        data[0:140][:, 110:150] = np.random.rand(140, 40) * noise + centers[2]
        data[0:55][:, 130:150] = (np.random.rand(55, 20) * noise + centers[3]) + data[0:55][:, 130:150]
    elif option == 'i':
        data[20:70][:, 20:70] = np.random.rand(50, 50) * noise + centers[0]
        data[20:70][:, 100:150] = np.random.rand(50, 50) * noise + centers[1]
        data[50:110][:, 50:120] = np.random.rand(60, 70) * noise + centers[2]
        data[120:150][:, 20:100] = np.random.rand(30, 80) * noise + centers[3]

    if shuffle:
        np.random.shuffle(data)
        np.random.shuffle(data.T)

    return data, y_row, y_col

# %%
X, y_row, y_col = generate_dataset('e', noise_background=False)
plt.matshow(X.T, cmap=plt.cm.Blues)
# plt.title('data')
plt.grid()
plt.show()

# %%
h5f = h5py.File('data.h5','w')
h5f.create_dataset('X', data=X.T) 
h5f.close()

# %%
k = 5
l = 3

# %%
# %%time
k = 5
l = 2
proc = subprocess.Popen(['./algos', 'binovnmtf', str(k), str(l), '100000'],
                        stdin = subprocess.PIPE,
                        stdout = subprocess.PIPE,
                        stderr = subprocess.PIPE)

(out, err) = proc.communicate()
print 'out:', out
print 'err:', err
# Out:
# out: Reading X...  read 150 rows and 150 cols!
# U S V created
# Computing S... done!
# Computing V...
#   - for cluster 0... done!
#   - for cluster 1... done!
#   - for cluster 2... done!
#   - for cluster 3... done!
#   - for cluster 4... done!
# Done computed V!
# Computing U... done!
# Error obtained: 23351907.79336075857
# Computing S... done!
# Computing V...
#   - for cluster 0... done!
#   - for cluster 1...observations_cluster_i empty!!!!
#   - for cluster 2... done!
#   - for cluster 3...observations_cluster_i empty!!!!
#   - for cluster 4...observations_cluster_i empty!!!!
# Done computed V!
# Computing U... done!
# Error obtained: 18947951.21042517200
# Computing S... done!
# Computing V...
#   - for cluster 0... done!
#   - for cluster 1...observations_cluster_i empty!!!!
#   - for cluster 2... done!
#   - for cluster 3...observations_cluster_i empty!!!!
#   - for cluster 4...observations_cluster_i empty!!!!
# Done computed V!
# Computing U... done!
# Error obtained: 8714929.17141235247
# Computing S... done!
# Computing V...
#   - for cluster 0... done!
#   - for cluster 1... done!
#   - for cluster 2... done!
#   - for cluster 3...observations_cluster_i empty!!!!
#   - for cluster 4...observations_cluster_i empty!!!!
# Done computed V!
# Computing U... done!
# Error obtained: 3235785.45028523915
# Computing S... done!
# Computing V...
#   - for cluster 0... done!
#   - for cluster 1... done!
#   - for cluster 2... done!
#   - for cluster 3...observations_cluster_i empty!!!!
#   - for cluster 4...observations_cluster_i empty!!!!
# Done computed V!
# Computing U... done!
# Error obtained: 2743711.19908188004
# Computing S... done!
# Computing V...
#   - for cluster 0... done!
#   - for cluster 1... done!
#   - for cluster 2... done!
#   - for cluster 3...observations_cluster_i empty!!!!
#   - for cluster 4...observations_cluster_i empty!!!!
# Done computed V!
# Computing U... done!
# Error obtained: 2743711.19908188004
# Time taken: 0.02168900000
#
# err:
# CPU times: user 1.5 ms, sys: 6.23 ms, total: 7.74 ms
# Wall time: 34.5 ms

# %%
k = 5
l = 2
U = genfromtxt('U.csv', delimiter=',')
S = genfromtxt('S.csv', delimiter=',')
R = genfromtxt('Reconstruction.csv', delimiter=',')
h5f = h5py.File('V.hdf5','r')
V = h5f['dataset'][:]
h5f.close()

# %%
plt.matshow(U.T, cmap=plt.cm.Blues)
plt.title('U')
plt.grid()
plt.show()

# %%
plt.matshow(S.T, cmap=plt.cm.Blues)
plt.title('S')
plt.grid()
plt.show()

# %%
for i in xrange(k):
    plt.matshow(V[i], cmap=plt.cm.Blues)
    plt.title('V[%s]' % i)
    plt.grid()
    plt.show()

# %%
plt.matshow(R, cmap=plt.cm.Blues)
plt.title('recostruction')
plt.grid()
plt.show()
